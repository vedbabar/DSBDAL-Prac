# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = r"C:\Users\vedba\Documents\DSBDAL_prac\tips.csv"
df = pd.read_csv(url)
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# group by a categorical variable, to show stats
summary_stats = df.groupby('day')['total_bill'].agg(
    Mean='mean',
    Median='median',
    Minimum='min',
    Maximum='max',
    Std_dev='std'
)
display(summary_stats)
# Out:
#            Mean  Median  Minimum  Maximum   Std_dev
# day
# Fri   17.151579   15.38     5.75    40.17  8.302660
# Sat   20.441379   18.24     3.07    50.81  9.480419
# Sun   21.410000   19.63     7.25    48.17  8.832122
# Thur  17.682742   16.20     7.51    43.11  7.886170

# %%
df.groupby('day').describe()
# Out:
#      total_bill                                                             \
#           count       mean       std   min      25%    50%      75%    max
# day
# Fri        19.0  17.151579  8.302660  5.75  12.0950  15.38  21.7500  40.17
# Sat        87.0  20.441379  9.480419  3.07  13.9050  18.24  24.7400  50.81
# Sun        76.0  21.410000  8.832122  7.25  14.9875  19.63  25.5975  48.17
# Thur       62.0  17.682742  7.886170  7.51  12.4425  16.20  20.1550  43.11
#
#        tip            ...                 size                                \
#      count      mean  ...     75%    max count      mean       std  min  25%
# day                   ...
# Fri   19.0  2.734737  ...  3.3650   4.73  19.0  2.105263  0.567131  1.0  2.0
# Sat   87.0  2.993103  ...  3.3700  10.00  87.0  2.517241  0.819275  1.0  2.0
# Sun   76.0  3.255132  ...  4.0000   6.50  76.0  2.842105  1.007341  2.0  2.0
# Thur  62.0  2.771452  ...  3.3625   6.70  62.0  2.451613  1.066285  1.0  2.0
#
#
# ...

# %%
url = r"C:\Users\vedba\Documents\DSBDAL_prac\iris.csv"
df=pd.read_csv(url)
df.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
stats = df.groupby('variety').describe()

# 3. Display the statistics
print("Statistical details for each species:")
print(stats)

# Optional: If the output is too wide, you can print the transpose (T)
# This will make the output look like a tall table, which is easier to read
print("\nTransposed view (easier to read):")
print(stats.T)
# Out:
# Statistical details for each species:
#            sepal.length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# variety
# Setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal.width         ... petal.length      petal.width         \
#                  count   mean  ...          75%  max       count   mean
# variety                        ...
# Setosa            50.0  3.428  ...        1.575  1.9        50.0  0.246
# Versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# Virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# variety
# Setosa      0.105386  0.1  0.2  0.2  0.3  0.6
# Versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# ...
