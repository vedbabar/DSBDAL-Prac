# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
url = r"C:\Users\vedba\Documents\DSBDAL_prac\titanic.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
df.shape
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Survived']=df['Survived'].astype('category')
df['Pclass']   = df['Pclass'].astype('category')
df['Sex']      = df['Sex'].astype('category')
df['Embarked'] = df['Embarked'].astype('category')
df.dtypes
# Out:
# PassengerId       int64
# Survived       category
# Pclass         category
# Name                str
# Sex            category
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket              str
# Fare            float64
# Cabin               str
# Embarked       category
# dtype: object

# %%
df['Age']=df['Age'].fillna(df['Age'].median())
df['Cabin']=df['Cabin'].fillna('Unknown')
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
scaler = MinMaxScaler()
df[['Age_Norm','Fare_Norm']]=scaler.fit_transform(df[['Age','Fare']])
df[['Age', 'Age_Norm', 'Fare', 'Fare_Norm']].head(8)
# Out:
#     Age  Age_Norm     Fare  Fare_Norm
# 0  22.0  0.271174   7.2500   0.014151
# 1  38.0  0.472229  71.2833   0.139136
# 2  26.0  0.321438   7.9250   0.015469
# 3  35.0  0.434531  53.1000   0.103644
# 4  35.0  0.434531   8.0500   0.015713
# 5   NaN       NaN   8.4583   0.016510
# 6  54.0  0.673285  51.8625   0.101229
# 7   2.0  0.019854  21.0750   0.041136

# %%
le=LabelEncoder()
df['Sex_Encoded']=le.fit_transform(df['Sex'])
df[['Sex', 'Sex_Encoded']].head(6)
# Out:
#       Sex  Sex_Encoded
# 0    male            1
# 1  female            0
# 2  female            0
# 3  female            0
# 4    male            1
# 5    male            1

# %%
df = pd.get_dummies(df, columns=['Embarked'], dtype=int)

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Age_Norm  Fare_Norm  Embarked_C  \
# 0      0         A/5 21171   7.2500   NaN  0.271174   0.014151           0
# 1      0          PC 17599  71.2833   C85  0.472229   0.139136           1
# 2      0  STON/O2. 3101282   7.9250   NaN  0.321438   0.015469           0
# 3      0            113803  53.1000  C123  0.434531   0.103644           0
# 4      0            373450   8.0500   NaN  0.434531   0.015713           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1
